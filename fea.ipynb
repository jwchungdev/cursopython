# %%
print("Hello")
# Out:
# Hello

# %%
from random import random

# %%
import matplotlib.pyplot as plt

x = range(10)
y = [random()*100 for x in range(10)]
     
fig, ax = plt.subplots()
ax.plot(x,y)
plt.show()
